# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammad-Abbasi/Hello-World/blob/master/Copy_of_color_image_segentation_with_kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sklearn

# %%
from sklearn.cluster import k_means

# %%
# !pip install opencv-python

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as img

# %%
image = cv2.imread(r'/content/drive/MyDrive/boat_lake2.jpg')
image1 = img.imread(r'/content/drive/MyDrive/boat_lake2.jpg')

# %%
plt.imshow(image1)

# %%
import numpy as np
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
X_vect = img.reshape(-1, 3)

# %%
model = k_means(x_vect, n_clusters=4, init='k-mean++', max_iter=300, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fa10ed8400e9> in <module>()
# ----> 1 model = k_means(x_vect, n_clusters=4, init='k-mean++', max_iter=300, verbose=True)
#
# NameError: name 'x_vect' is not defined

# %%
for i in range(len(kmeans.labels_)):
  x_vext[i] = center[labels_[i]]
